# %%
#import libracies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Question 1/spotifytoptracks.csv')
data.head(5)
# Out:
#    Unnamed: 0       artist                                  album  \
# 0           0   The Weeknd                            After Hours
# 1           1  Tones And I                           Dance Monkey
# 2           2  Roddy Ricch  Please Excuse Me For Being Antisocial
# 3           3    SAINt JHN                  Roses (Imanbek Remix)
# 4           4     Dua Lipa                       Future Nostalgia
#
#               track_name                track_id  energy  danceability  key  \
# 0        Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1
# 1           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6
# 2                The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10
# 3  Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8
# 4        Don't Start Now  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11
#
#    loudness  acousticness  speechiness  instrumentalness  liveness  valence  \
# 0    -5.934       0.00146       0.0598          0.000095    0.0897    0.334
# 1    -6.401       0.68800       0.0988          0.000161    0.1700    0.540
# 2    -6.687       0.10400       0.0559          0.000000    0.7900    0.642
# 3    -5.457       0.01490       0.0506          0.004320    0.2850    0.894
# 4    -4.521       0.01230       0.0830          0.000000    0.0951    0.679
#
#      tempo  duration_ms              genre
# 0  171.005       200040           R&B/Soul
# 1   98.078       209755  Alternative/Indie
# 2  116.971       196653        Hip-Hop/Rap
# 3  121.962       176219   Dance/Electronic
# 4  123.950       183290           Nu-disco

# %%
 # data cleaning
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   artist            50 non-null     object
#  2   album             50 non-null     object
#  3   track_name        50 non-null     object
#  4   track_id          50 non-null     object
#  5   energy            50 non-null     float64
#  6   danceability      50 non-null     float64
#  7   key               50 non-null     int64
#  8   loudness          50 non-null     float64
#  9   acousticness      50 non-null     float64
#  10  speechiness       50 non-null     float64
#  11  instrumentalness  50 non-null     float64
#  12  liveness          50 non-null     float64
#  13  valence           50 non-null     float64
#  14  tempo             50 non-null     float64
#  15  duration_ms       50 non-null     int64
#  16  genre             50 non-null     object
# dtypes: float64(9), int64(3), object(5)
# memory usage: 6.8+ KB

# %%
# missing value
data.isna().sum()
# Out:
# Unnamed: 0          0
# artist              0
# album               0
# track_name          0
# track_id            0
# energy              0
# danceability        0
# key                 0
# loudness            0
# acousticness        0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# genre               0
# dtype: int64

# %%
# remove duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.drop("Unnamed: 0", axis=1, inplace=True)

data.head()
# Out:
#         artist                                  album             track_name  \
# 0   The Weeknd                            After Hours        Blinding Lights
# 1  Tones And I                           Dance Monkey           Dance Monkey
# 2  Roddy Ricch  Please Excuse Me For Being Antisocial                The Box
# 3    SAINt JHN                  Roses (Imanbek Remix)  Roses - Imanbek Remix
# 4     Dua Lipa                       Future Nostalgia        Don't Start Now
#
#                  track_id  energy  danceability  key  loudness  acousticness  \
# 0  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1    -5.934       0.00146
# 1  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6    -6.401       0.68800
# 2  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10    -6.687       0.10400
# 3  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8    -5.457       0.01490
# 4  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11    -4.521       0.01230
#
#    speechiness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.0598          0.000095    0.0897    0.334  171.005       200040
# 1       0.0988          0.000161    0.1700    0.540   98.078       209755
# 2       0.0559          0.000000    0.7900    0.642  116.971       196653
# 3       0.0506          0.004320    0.2850    0.894  121.962       176219
# 4       0.0830          0.000000    0.0951    0.679  123.950       183290
#
#                genre
# 0           R&B/Soul
# 1  Alternative/Indie
# 2        Hip-Hop/Rap
# 3   Dance/Electronic
# 4           Nu-disco

# %% [markdown]
# # **Outliner**

# %%
data.describe()
# Out:
#           energy  danceability        key   loudness  acousticness  \
# count  50.000000     50.000000  50.000000  50.000000     50.000000
# mean    0.609300      0.716720   5.720000  -6.225900      0.256206
# std     0.154348      0.124975   3.709007   2.349744      0.265250
# min     0.225000      0.351000   0.000000 -14.454000      0.001460
# 25%     0.494000      0.672500   2.000000  -7.552500      0.052800
# 50%     0.597000      0.746000   6.500000  -5.991500      0.188500
# 75%     0.729750      0.794500   8.750000  -4.285500      0.298750
# max     0.855000      0.935000  11.000000  -3.280000      0.934000
#
#        speechiness  instrumentalness   liveness    valence       tempo  \
# count    50.000000         50.000000  50.000000  50.000000   50.000000
# mean      0.124158          0.015962   0.196552   0.555710  119.690460
# std       0.116836          0.094312   0.176610   0.216386   25.414778
# min       0.029000          0.000000   0.057400   0.060500   75.801000
# 25%       0.048325          0.000000   0.093950   0.434000   99.557250
# 50%       0.070050          0.000000   0.111000   0.560000  116.969000
# 75%       0.155500          0.000020   0.271250   0.726250  132.317000
# max       0.487000          0.657000   0.792000   0.925000  180.067000
#
#          duration_ms
# count      50.000000
# mean   199955.360000
# std     33996.122488
# min    140526.000000
# 25%    175845.500000
# 50%    197853.500000
# 75%    215064.000000
# max    312820.000000

# %%
columns = ["energy", "danceability", "key", "loudness", "acousticness",
           "speechiness", "instrumentalness", "liveness", "valence",
           "tempo", "duration_ms"]

n_cols = 3
n_rows = (len(columns) // n_cols) + (1 if len(columns) % n_cols != 0 else 0)

# subplots to display all boxplots
plt.figure(figsize=(15, 10))

# Loop through the columns and create a boxplot for each feature
for i, col in enumerate(columns, 1):
    plt.subplot(n_rows, n_cols, i)
    data[col].plot(kind='box')
    plt.title(f'Boxplot for {col}')

plt.tight_layout()
plt.show()

# %%
# drop outliers based on IQR
def drop_outliers_iqr(data, columns):
    for col in columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1

        # lower and upper bounds for outlier detection
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filter out rows that fall outside the bounds
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]

    return data
data = drop_outliers_iqr(data, columns)

data.describe()
# Out:
#           energy  danceability        key   loudness  acousticness  \
# count  29.000000     29.000000  29.000000  29.000000     29.000000
# mean    0.627586      0.732172   5.965517  -5.858000      0.169434
# std     0.135089      0.098775   3.727147   1.874425      0.127540
# min     0.427000      0.511000   0.000000  -8.820000      0.010300
# 25%     0.522000      0.676000   2.000000  -7.509000      0.052200
# 50%     0.601000      0.755000   7.000000  -5.652000      0.183000
# 75%     0.729000      0.789000   9.000000  -4.209000      0.234000
# max     0.855000      0.935000  11.000000  -3.370000      0.533000
#
#        speechiness  instrumentalness   liveness    valence       tempo  \
# count    29.000000         29.000000  29.000000  29.000000   29.000000
# mean      0.125859          0.000002   0.178534   0.575845  118.767069
# std       0.114498          0.000005   0.115587   0.217232   27.747754
# min       0.029000          0.000000   0.062600   0.060500   76.469000
# 25%       0.046500          0.000000   0.093600   0.457000   96.172000
# 50%       0.080300          0.000000   0.118000   0.569000  116.735000
# 75%       0.164000          0.000000   0.272000   0.749000  130.049000
# max       0.389000          0.000025   0.460000   0.925000  180.067000
#
#          duration_ms
# count      29.000000
# mean   195629.103448
# std     35001.277387
# min    140526.000000
# 25%    166794.000000
# 50%    187541.000000
# 75%    212867.000000
# max    295177.000000

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
print(f"The number of observations is {data.shape[0]} and the number of features is {data.shape[1]}")
# Out:
# The number of observations is 29 and the number of features is 16

# %%
# Count of categorical and numeric columns
category = data.select_dtypes(include=['object', 'category']).columns
numeric = data.select_dtypes(include=['number']).columns

# Number of categorical and numeric columns
print(f"The number of categorical columns: {len(category)}")
print(f"The number of numeric columns: {len(numeric)}")
# Out:
# The number of categorical columns: 5
# The number of numeric columns: 11

# %%
# most popular track
popular_track = data.groupby('artist')['track_name'].count()
artists_rate = popular_track[popular_track > 1]
print(artists_rate)
# Out:
# artist
# Dua Lipa         2
# Harry Styles     2
# Justin Bieber    2
# Travis Scott     2
# Name: track_name, dtype: int64

# %%
# Artist most popular
artist = data.groupby('artist')['artist'].count()
most_popular = artist[artist>1]
most_popular
# Out:
# artist
# Dua Lipa         2
# Harry Styles     2
# Justin Bieber    2
# Travis Scott     2
# Name: artist, dtype: int64

# %%
# Total artist in total
num_artists = data['artist'].nunique()
print(f"The number of artists in the top 50 is {num_artists}")
# Out:
# The number of artists in the top 50 is 25

# %%
# How many albums in total have their songs in the top 50?
track_count = data.groupby('album')['track_name'].count()
album_count = track_count[track_count].count()
print("The album in the data are ",album_count)
# Out:
# The album in the data are  26

# %%
# Count the number of unique albums in the top 50
num_albums= data['album'].nunique()
print(f"The number of albums in the top 50 is {num_albums}")
# Out:
# The number of albums in the top 50 is 26

# %%
# tracks with danceability above 0.7
tracks= data[data['danceability'] > 0.7]
print(tracks[['track_name', 'artist', 'danceability']])
# Out:
#                                        track_name         artist  danceability
# 4                                 Don't Start Now       Dua Lipa         0.793
# 5                    ROCKSTAR (feat. Roddy Ricch)         DaBaby         0.746
# 8                                         Falling  Trevor Daniel         0.784
# 13                                Blueberry Faygo      Lil Mosey         0.774
# 14                       Intentions (feat. Quavo)  Justin Bieber         0.806
# 15                                   Toosie Slide          Drake         0.830
# 17                                         Say So       Doja Cat         0.787
# 20               Savage Love (Laxed - Siren Beat)      Jawsh 685         0.767
# 22                                    Breaking Me          Topic         0.789
# 25                                       Señorita   Shawn Mendes         0.759
# 27                WAP (feat. Megan Thee Stallion)        Cardi B         0.935
# 28                                    Sunday Best       Surfaces         0.878
# 29                    Godzilla (feat. Juice WRLD)         Eminem         0.808
# 31                                 Break My Heart       Dua Lipa         0.730
# 32                                       Dynamite            BTS         0.746
# 37  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone         0.755
# 38                                          Hawái         Maluma         0.783
# 40                                     goosebumps   Travis Scott         0.841
# 42                                     THE SCOTTS     THE SCOTTS         0.716

# %%
# tracks with danceability below 0.4
tracks = data[data['danceability'] < 0.4]
print(tracks[['track_name', 'artist', 'danceability']])
# Out:
# Empty DataFrame
# Columns: [track_name, artist, danceability]
# Index: []

# %%
# tracks with loudness above -5
tracks = data[data['loudness'] > -5]
print(tracks[['track_name', 'artist', 'loudness']])
# Out:
#                                        track_name        artist  loudness
# 4                                 Don't Start Now      Dua Lipa    -4.521
# 6                                Watermelon Sugar  Harry Styles    -4.209
# 17                                         Say So      Doja Cat    -4.577
# 21                                      Adore You  Harry Styles    -3.675
# 23                         Mood (feat. iann dior)      24kGoldn    -3.558
# 31                                 Break My Heart      Dua Lipa    -3.434
# 32                                       Dynamite           BTS    -4.410
# 35                Rain On Me (with Ariana Grande)     Lady Gaga    -3.764
# 37  Sunflower - Spider-Man: Into the Spider-Verse   Post Malone    -4.368
# 38                                          Hawái        Maluma    -3.454
# 40                                     goosebumps  Travis Scott    -3.370
# 43                                        Safaera     Bad Bunny    -4.074

# %%
# tracks with loudness above -8
tracks = data[data['loudness'] < -8]
print(tracks[['track_name', 'artist', 'loudness']])
# Out:
#                           track_name         artist  loudness
# 8                            Falling  Trevor Daniel    -8.756
# 15                      Toosie Slide          Drake    -8.820
# 20  Savage Love (Laxed - Siren Beat)      Jawsh 685    -8.520
# 36               HIGHEST IN THE ROOM   Travis Scott    -8.764

# %%
# track with the longest duration
longest = data.loc[data['duration_ms'].idxmax()]
print(f"The longest track is {longest['track_name']} by {longest['artist']} with {longest['duration_ms']}")
# Out:
# The longest track is Safaera by Bad Bunny with 295177

# %%
# track with the shortest duration
shortest = data.loc[data['duration_ms'].idxmin()]
print(f"The shortest track is {shortest['track_name']} by {shortest['artist']} with {shortest['duration_ms']} ")
# Out:
# The shortest track is Mood (feat. iann dior) by 24kGoldn with 140526

# %%
#  genre most popular
most_popular_genre = data.groupby('genre')['genre'].max().idxmax()
print(f"The most popular genre is {most_popular_genre}")
# Out:
# The most popular genre is R&B/Soul

# %%
# genre with one song on the top 50
genre = data.groupby('genre')['genre'].count()
one_song = genre[genre == 1]
print(one_song)
# Out:
# genre
#  Electro-pop                          1
# Alternative/reggaeton/experimental    1
# Dance-pop/Disco                       1
# Dance/Electronic                      1
# Disco-pop                             1
# Dreampop/Hip-Hop/R&B                  1
# Hip-Hop/Trap                          1
# Nu-disco                              1
# Pop rap                               1
# R&B/Hip-Hop alternative               1
# R&B/Soul                              1
# Name: genre, dtype: int64

# %%
#count of genres
num_genres = data['genre'].nunique()
print(f"The number of genres in the top 50 is {num_genres}")
# Out:
# The number of genres in the top 50 is 13

# %%
# Selecting numeric features
numeric_features = ["energy", "danceability", "key", "loudness", "acousticness",
           "speechiness", "liveness", "valence", "tempo", "duration_ms"]

# Calculating correlation matrix
correlation_matrix = data[numeric_features].corr()

# Plotting correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %%
# Strongly positively correlated
positive_corr = correlation_matrix[correlation_matrix > 0.5]
positive_corr = positive_corr[positive_corr != 1]
print("Strongly positively correlated features:")
print(positive_corr.dropna(how='all', axis=1))
# Out:
# Strongly positively correlated features:
#                 energy  loudness
# energy             NaN  0.809401
# danceability       NaN       NaN
# key                NaN       NaN
# loudness      0.809401       NaN
# acousticness       NaN       NaN
# speechiness        NaN       NaN
# liveness           NaN       NaN
# valence            NaN       NaN
# tempo              NaN       NaN
# duration_ms        NaN       NaN

# %%
# Step 2: Strongly negatively correlated features
negative_corr = correlation_matrix[correlation_matrix < -0.5]
negative_corr = negative_corr[negative_corr != -1]
print("\nStrongly negatively correlated features:")
print(negative_corr.dropna(how='all', axis=1))
# Out:
# Strongly negatively correlated features:
#               danceability  liveness
# energy                 NaN       NaN
# danceability           NaN -0.606233
# key                    NaN       NaN
# loudness               NaN       NaN
# acousticness           NaN       NaN
# speechiness            NaN       NaN
# liveness         -0.606233       NaN
# valence                NaN       NaN
# tempo                  NaN       NaN
# duration_ms            NaN       NaN

# %%
# Step 3: Features that are not correlated
no_corr = correlation_matrix[(correlation_matrix > -0.1) & (correlation_matrix < 0.1) & (correlation_matrix != 1)]
print("\nFeatures that are not correlated:")
print(no_corr.dropna(how='all', axis=1))
# Out:
# Features that are not correlated:
#                 energy  danceability       key  loudness  acousticness  \
# energy             NaN           NaN       NaN       NaN           NaN
# danceability       NaN           NaN  0.028247       NaN      0.001844
# key                NaN      0.028247       NaN       NaN           NaN
# loudness           NaN           NaN       NaN       NaN           NaN
# acousticness       NaN      0.001844       NaN       NaN           NaN
# speechiness        NaN           NaN -0.095049  0.078083     -0.084417
# liveness      0.097277           NaN -0.077774  0.095571     -0.064419
# valence            NaN           NaN  0.086913       NaN           NaN
# tempo        -0.074497           NaN       NaN  0.072430     -0.031585
# duration_ms        NaN           NaN  0.057338       NaN     -0.067889
#
#               speechiness  liveness   valence     tempo  duration_ms
# energy                NaN  0.097277       NaN -0.074497          NaN
# danceability          NaN       NaN       NaN       NaN          NaN
# key             -0.095049 -0.077774  0.086913       NaN     0.057338
# loudness         0.078083  0.095571       NaN  0.072430          NaN
# acousticness    -0.084417 -0.064419       NaN -0.031585    -0.067889
# speechiness           NaN       NaN  0.091622       NaN          NaN
# liveness              NaN       NaN       NaN  0.065063    -0.028586
# valence          0.091622       NaN       NaN       NaN          NaN
# tempo                 NaN  0.065063       NaN       NaN     0.055125
# duration_ms           NaN -0.028586       NaN  0.055125          NaN

# %%
data['genre'].unique()
# Out:
# array(['Nu-disco', 'Hip-Hop/Rap', 'Pop', 'R&B/Hip-Hop alternative',
#        'R&B/Soul', 'Dance/Electronic', 'Pop rap', 'Hip-Hop/Trap',
#        ' Electro-pop', 'Dance-pop/Disco', 'Disco-pop',
#        'Dreampop/Hip-Hop/R&B', 'Alternative/reggaeton/experimental'],
#       dtype=object)

# %%
# danceability score comparism
genre = ['Pop', 'Hip-Hop/Rap', 'Dance/Electronic', 'Alternative/Indie']
comparism = data_genre.groupby('genre')['danceability'].describe()
comparism  = comparism .loc[:, ['count', 'mean', 'std', 'min', 'max']]
print(comparism )
# Out:
#                   count      mean       std    min    max
# genre
# Dance/Electronic    1.0  0.789000       NaN  0.789  0.789
# Hip-Hop/Rap         9.0  0.744556  0.086285  0.598  0.841
# Pop                 9.0  0.669778  0.102929  0.511  0.806

# %%
# loudness score comparism
comparism = data_genre.groupby('genre')['loudness'].describe()
comparism  = comparism .loc[:, ['count', 'mean', 'std', 'min', 'max']]
print(comparism )
# Out:
#                   count      mean       std    min    max
# genre
# Dance/Electronic    1.0 -5.652000       NaN -5.652 -5.652
# Hip-Hop/Rap         9.0 -7.095889  1.901704 -8.820 -3.370
# Pop                 9.0 -5.369778  1.553208 -7.230 -3.454

# %%
# Acousticnes score comparism
comparism = data_genre.groupby('genre')['acousticness'].describe()
comparism  = comparism .loc[:, ['count', 'mean', 'std', 'min', 'max']]
print(comparism )
# Out:
#                   count      mean       std     min    max
# genre
# Dance/Electronic    1.0  0.223000       NaN  0.2230  0.223
# Hip-Hop/Rap         9.0  0.171833  0.089853  0.0522  0.289
# Pop                 9.0  0.178656  0.134603  0.0210  0.349
